# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from skimage import filters

# %% [markdown]
# Temporary directory where real images will be drawn to perform convolutions and generate data

# %%
input_directory = '../data/FakeFaces'

# %%
fake_faces = os.listdir(os.fsencode(input_directory))

# %% [markdown]
# Iterate through every file in the directory and perform convolution then save in respective folder

# %%
for file in fake_faces:
    filename = os.fsdecode(file)
    
    # Read in image and convert it into a grayscale numpy array
    img = np.array(Image.open(input_directory + '/' + filename))[:,:,0]
    
    # Perform convolutions and save image
    edges = filters.sobel(img)  
    plt.imshow(edges)
    plt.show()
# Out:
# (1024, 1024)
# (1024, 1024)
